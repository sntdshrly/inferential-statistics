# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(0.105 * 0.915) + (0.1*0.915)
# Out:
# 0.187575

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(0.1 * 0.85)/(0.187575)
# Out:
# 0.45315207250433165

# %%
1-((0.1 * 0.85)/(0.187575) )
# Out:
# 0.5468479274956684
